# %%
pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in c:\users\hsc-pc\appdata\local\programs\python\python313\lib\site-packages (9.7.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install PyMySQL
# Out:
# Requirement already satisfied: PyMySQL in c:\users\hsc-pc\appdata\local\programs\python\python313\lib\site-packages (1.2.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # 1. Backup

# %%
import mysql.connector
from datetime import datetime

# %%
Connection = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",                #Put your MySQL passwords
    database="LibraryReservationDB"
)
cursor = Connection.cursor()
print("Connected to the database successfully!")
# Out:
# Connected to the database successfully!

# %%
cursor.execute("SHOW TABLES")

tables = cursor.fetchall()

for table in tables:
    print(table[0])
# Out:
# feedback
# library_table
# notification
# reservation_record
# seat
# user
